# %% [markdown]
# <a href="https://colab.research.google.com/github/dantrainor9/Medicare-Analysis/blob/main/Medicare_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/Medicare project/PGYR22_P011824/OP_DTL_GNRL_PGYR2022_P01182024.csv'

# %%
#importing a reduced dataset for the sake of RAM
df1 = pd.read_csv(path,nrows=2000000)
df1.head()

# %%
pd.set_option('display.max_columns', 81)
pd.set_option('display.max_rows',81)

# %%
df1.shape
# Out:
# (2000000, 91)

# %%
df1.describe()
# Out:
#        Teaching_Hospital_CCN  Teaching_Hospital_ID  \
# count            4682.000000           4682.000000
# mean           283918.473302          11986.581589
# std            137393.106071            437.138107
# min             10001.000000          11336.000000
# 25%            180030.500000          11581.000000
# 50%            330059.000000          11987.000000
# 75%            390063.000000          12395.000000
# max            670034.000000          12715.000000
#
#        Covered_Recipient_Profile_ID  Covered_Recipient_NPI  \
# count                  1.995318e+06           1.993667e+06
# mean                   4.826460e+06           1.498186e+09
# std                    5.007834e+06           2.884768e+08
# min                    5.000000e+00           1.003000e+09
# 25%                    2.455910e+05           1.245553e+09
# 50%                    1.255467e+06           1.497899e+09
# 75%                    1.073069e+07           1.740785e+09
# ...

# %%
df1.isna().sum()
# Out:
# Change_Type                                                       0
# Covered_Recipient_Type                                            0
# Teaching_Hospital_CCN                                       1995318
# Teaching_Hospital_ID                                        1995318
# Teaching_Hospital_Name                                      1995318
#                                                              ...
# Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5    1994414
# Associated_Drug_or_Biological_NDC_5                         2000000
# Associated_Device_or_Medical_Supply_PDI_5                   1998584
# Program_Year                                                      0
# Payment_Publication_Date                                          0
# Length: 91, dtype: int64

# %%
df1 = df1.drop(columns=['Covered_Recipient_Primary_Type_3','Covered_Recipient_Primary_Type_4','Covered_Recipient_Primary_Type_5','Covered_Recipient_Primary_Type_6',
                      'Covered_Recipient_Specialty_2','Covered_Recipient_Specialty_3','Covered_Recipient_Specialty_4','Covered_Recipient_Specialty_5','Covered_Recipient_Specialty_6',
                      'Associated_Drug_or_Biological_NDC_5'])

# %%
df1.describe()
# Out:
#        Teaching_Hospital_CCN  Teaching_Hospital_ID  \
# count            4682.000000           4682.000000
# mean           283918.473302          11986.581589
# std            137393.106071            437.138107
# min             10001.000000          11336.000000
# 25%            180030.500000          11581.000000
# 50%            330059.000000          11987.000000
# 75%            390063.000000          12395.000000
# max            670034.000000          12715.000000
#
#        Covered_Recipient_Profile_ID  Covered_Recipient_NPI  \
# count                  1.995318e+06           1.993667e+06
# mean                   4.826460e+06           1.498186e+09
# std                    5.007834e+06           2.884768e+08
# min                    5.000000e+00           1.003000e+09
# 25%                    2.455910e+05           1.245553e+09
# 50%                    1.255467e+06           1.497899e+09
# 75%                    1.073069e+07           1.740785e+09
# ...

# %%
df1.isna().sum()
# Out:
# Change_Type                                                                0
# Covered_Recipient_Type                                                     0
# Teaching_Hospital_CCN                                                1995318
# Teaching_Hospital_ID                                                 1995318
# Teaching_Hospital_Name                                               1995318
# Covered_Recipient_Profile_ID                                            4682
# Covered_Recipient_NPI                                                   6333
# Covered_Recipient_First_Name                                            4698
# Covered_Recipient_Middle_Name                                         632733
# Covered_Recipient_Last_Name                                             4728
# Covered_Recipient_Name_Suffix                                        1965371
# Recipient_Primary_Business_Street_Address_Line1                            3
# ...

# %%
#making a dataframe of only those columns with primarily non-null values
df = pd.read_csv(path,usecols=['Covered_Recipient_Type','Covered_Recipient_NPI','Recipient_City','Recipient_Zip_Code','Covered_Recipient_Primary_Type_1','Covered_Recipient_Specialty_1',
                               'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name','Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
                               'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
                               'Total_Amount_of_Payment_USDollars','Date_of_Payment','Number_of_Payments_Included_in_Total_Amount',
                               'Form_of_Payment_or_Transfer_of_Value','Nature_of_Payment_or_Transfer_of_Value',
                               'Third_Party_Payment_Recipient_Indicator','Delay_in_Publication_Indicator','Dispute_Status_for_Publication','Related_Product_Indicator',
                               'Covered_or_Noncovered_Indicator_1','Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1','Product_Category_or_Therapeutic_Area_1',
                               'Associated_Drug_or_Biological_NDC_1'])
# Out:
# <ipython-input-3-9d1381924c9f>:1: DtypeWarning: Columns (15,60,61,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,usecols=['Covered_Recipient_Type','Covered_Recipient_NPI','Recipient_City','Recipient_Zip_Code','Covered_Recipient_Primary_Type_1','Covered_Recipient_Specialty_1',

# %%
df.head()
# Out:
#         Covered_Recipient_Type  Covered_Recipient_NPI Recipient_City  \
# 0  Covered Recipient Physician           1.154649e+09       ONALASKA
# 1  Covered Recipient Physician           1.588059e+09   CRYSTAL LAKE
# 2  Covered Recipient Physician           1.588059e+09   CRYSTAL LAKE
# 3  Covered Recipient Physician           1.609230e+09      MILWAUKEE
# 4  Covered Recipient Physician           1.740774e+09       PEWAUKEE
#
#   Recipient_Zip_Code Covered_Recipient_Primary_Type_1  \
# 0         54650-8447                   Medical Doctor
# 1         60012-3709                   Medical Doctor
# 2         60012-3709                   Medical Doctor
# 3         53226-3595             Doctor of Osteopathy
# 4         53072-5591     Doctor of Podiatric Medicine
#
#                        Covered_Recipient_Specialty_1  \
# 0  Allopathic & Osteopathic Physicians|Orthopaedi...
# 1  Allopathic & Osteopathic Physicians|Orthopaedi...
# 2  Allopathic & Osteopathic Physicians|Orthopaedi...
# ...

# %%
df.shape
# Out:
# (13151823, 22)

# %%
df.describe()
# Out:
# <bound method NDFrame.describe of                Covered_Recipient_Type  Covered_Recipient_NPI Recipient_City  \
# 0         Covered Recipient Physician           1.154649e+09       ONALASKA
# 1         Covered Recipient Physician           1.588059e+09   CRYSTAL LAKE
# 2         Covered Recipient Physician           1.588059e+09   CRYSTAL LAKE
# 3         Covered Recipient Physician           1.609230e+09      MILWAUKEE
# 4         Covered Recipient Physician           1.740774e+09       PEWAUKEE
# ...                               ...                    ...            ...
# 13151818  Covered Recipient Physician           1.326277e+09     BURLINGTON
# 13151819  Covered Recipient Physician           1.326277e+09     BURLINGTON
# 13151820  Covered Recipient Physician           1.699742e+09         BEXLEY
# 13151821  Covered Recipient Physician           1.699742e+09         BEXLEY
# 13151822  Covered Recipient Physician           1.699742e+09         BEXLEY
#
# ...
